# %%
import pandas as pd

# %%
url = "C:\Users\Murthy\Desktop\Jaideep Folder\Internship\ApnaGuide\Churn-Data.csv"

# %%
df = pd.read_csv(url)

# %%
import pandas as pd

# Replace 'file_path' with the actual path to your dataset file
file_path = 'C:/Users/Murthy/Desktop/Jaideep Folder/Internship/ApnaGuide/Churn-Data.csv'

# Load the dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# Now you can work with the 'df' DataFrame in your Jupyter Notebook

# %%
import pandas as pd

# %%
file_path = 'C:/Users/Murthy/Desktop/Jaideep Folder/Internship/ApnaGuide/Churn-Data.csv'

# %%
df = pd.read_csv(file_path)

# %%
pd.to_numeric(df.totalcharges, errors='coerce')
# Out:
# 0       1336.80
# 1       5129.45
# 2         23.45
# 3        237.95
# 4          0.00
#          ...
# 5629      95.00
# 5630    2198.30
# 5631     306.05
# 5632    1200.15
# 5633     457.30
# Name: totalcharges, Length: 5634, dtype: float64

# %%
# View the columns of the DataFrame
df.columns
# Out:
# Index(['cID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'TV_Streaming',
#        'Movie_Streaming', 'Contract', 'PaperlessBilling', 'Method_Payment',
#        'Charges_Month', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

string_columns = list(df.dtypes[df.dtypes == 'object'].index)

for col in string_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
# View the columns of the DataFrame
df.columns
# Out:
# Index(['cid', 'gender', 'seniorcitizen', 'partner', 'dependents', 'tenure',
#        'phoneservice', 'multiplelines', 'internetservice', 'onlinesecurity',
#        'onlinebackup', 'deviceprotection', 'techsupport', 'tv_streaming',
#        'movie_streaming', 'contract', 'paperlessbilling', 'method_payment',
#        'charges_month', 'totalcharges', 'churn'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

string_columns = list(df.dtypes[df.dtypes == 'object'].index)

for col in string_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
 from sklearn.model_selection import train_test_split

# %%
train_test_split(df, test_size=0.2, random)
# Out:
# [             cid  gender  seniorcitizen partner dependents  tenure  \
#  2365  6234-pfpxl    male              0     yes         no      22
#  1300  8224-uaxbz  female              0     yes         no      58
#  3251  7777-unyhb  female              0     yes        yes      12
#  2354  3340-qbbfm    male              1     yes         no      36
#  579   8748-hfwbo    male              0     yes        yes      19
#  ...          ...     ...            ...     ...        ...     ...
#  905   7740-btpux    male              1     yes         no      55
#  5192  8670-ercjh    male              0      no         no      72
#  3980  7820-zygny    male              0      no         no      63
#  235   9746-ugfac  female              0      no         no      22
#  5157  2129-alkbs  female              0     yes        yes      40
#
#       phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# ...

# %%
import pandas as pd

# Creating a DataFrame
data = {'column1': [1, 2, 3], 'column2': ['a', 'b', 'c']}
df_full_train = pd.DataFrame(data)

# Now you can use df_full_train
print(df_full_train)
# Out:
#    column1 column2
# 0        1       a
# 1        2       b
# 2        3       c

# %%
df_full_train
# Out:
#    column1 column2
# 0        1       a
# 1        2       b
# 2        3       c

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

string_columns = list(df.dtypes[df.dtypes == 'object'].index)

for col in string_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)

# %%
df_train, df_val = train_test_split(df, test_size=0.25, random_state=1)

# %%
# Assuming 'test' is supposed to be a DataFrame
# Define the 'test' DataFrame before using it
test = pd.DataFrame()

# Now you can use the variable 'test' in the code
len(df_train), len(df_val), len(test)
# Out:
# (4225, 1409, 0)

# %%
y_train = (df_train.churn == 'yes').astype('int')
y_val = (df_val.churn == 'yes').astype('int')
y_test = (df_test.churn == 'yes').astype('int')

# %%
y_train
# Out:
# 330     0
# 4478    1
# 3576    1
# 32      0
# 1438    0
#        ..
# 905     0
# 5192    0
# 3980    0
# 235     0
# 5157    0
# Name: churn, Length: 4225, dtype: int32

# %%
df_train
# Out:
#              cid  gender  seniorcitizen partner dependents  tenure  \
# 330   2680-xkknj  female              0      no         no       8
# 4478  0634-szpqa  female              0      no         no      23
# 3576  6376-gahqe    male              0      no         no       4
# 32    9139-twbas  female              0     yes         no      26
# 1438  1421-hcerk    male              1     yes         no      30
# ...          ...     ...            ...     ...        ...     ...
# 905   7740-btpux    male              1     yes         no      55
# 5192  8670-ercjh    male              0      no         no      72
# 3980  7820-zygny    male              0      no         no      63
# 235   9746-ugfac  female              0      no         no      22
# 5157  2129-alkbs  female              0     yes        yes      40
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 330           yes                no             dsl                  yes  ...
# ...

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
if 'customerid' in df_train:
    del df_train['cid']
if 'churn' in df_train:
    del df_train['churn']

# %%
df_train
# Out:
#              cid  gender  seniorcitizen partner dependents  tenure  \
# 330   2680-xkknj  female              0      no         no       8
# 4478  0634-szpqa  female              0      no         no      23
# 3576  6376-gahqe    male              0      no         no       4
# 32    9139-twbas  female              0     yes         no      26
# 1438  1421-hcerk    male              1     yes         no      30
# ...          ...     ...            ...     ...        ...     ...
# 905   7740-btpux    male              1     yes         no      55
# 5192  8670-ercjh    male              0      no         no      72
# 3980  7820-zygny    male              0      no         no      63
# 235   9746-ugfac  female              0      no         no      22
# 5157  2129-alkbs  female              0     yes        yes      40
#
#      phoneservice     multiplelines internetservice       onlinesecurity  \
# 330           yes                no             dsl                  yes
# ...

# %%
if 'cid' in df_train:
    del df_train['cid']
if 'churn' in df_train:
    del df_train['churn']

# %%
dict_train = df_train.to_dict(orient='records')

# %%
dict_train[:5]
# Out:
# [{'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'tenure': 8,
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'tv_streaming': 'no',
#   'movie_streaming': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'method_payment': 'bank_transfer_(automatic)',
#   'charges_month': 58.2,
#   'totalcharges': '469.25'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'tenure': 23,
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'tv_streaming': 'yes',
#   'movie_streaming': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
# ...

# %%
dv = DictVectorizer()
# Assuming data_dict is the input data in dictionary format
data_dict = [{'feature1': 1, 'feature2': 2}, {'feature1': 3, 'feature2': 4}]
dv.fit(data_dict)
# Out:
# DictVectorizer()

# %%
X_train = dv.transform(dict_train)

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# model = LogisticRegrassion(max_iter=1000)

# %%
# Assuming 'model' is a pre-defined model object from a machine learning library like scikit-learn
from sklearn.linear_model import LinearRegression  # Importing Linear Regression model as an example

model = LinearRegression()  # Creating an instance of the Linear Regression model
model.fit(X_train, y_train)  # Fitting the model to the training data
# Out:
# LinearRegression()

# %%
if 'cid' in df_train:
    del df_val['cid']
if 'churn' in df_train:
    del df_val['churn']

# %%
dict_val = df_val.to_dict(orient='records')

# %%
X_val = dv.transform(dict_val)

# %%
model.predict(X_val)
# Out:
# array([0.26911243, 0.26911243, 0.26911243, ..., 0.26911243, 0.26911243,
#        0.26911243])

# %%
# Assuming 'model' is the trained model and X_val is the validation data
threshold = 0.5  # Define the threshold for binary classification

# Get the continuous predictions from the model
continuous_predictions = model.predict(X_val)

# Convert the continuous predictions to binary (0 or 1) based on the threshold
binary_predictions = [1 if pred > threshold else 0 for pred in continuous_predictions]

# %%
model.predict(X_val)
# Out:
# array([0.26911243, 0.26911243, 0.26911243, ..., 0.26911243, 0.26911243,
#        0.26911243])

# %%
y_pred = model.predict(X_val)

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Assistant
# This error occurs because the `accuracy_score` function is expecting binary (0 or 1) labels, but it seems that the `y_val` or `y_pred` contains continuous values instead of binary values.
#
# To fix this error, you need to ensure that `y_val` and `y_pred` contain binary values (0 or 1) for classification accuracy calculation.
#
# Would you like me to provide the corrected code?

# %%
import numpy as np

# %%
from sklearn.metrics import accuracy_score

# %%
threshold = 0.5
y_pred_binary = np.where(y_pred >= threshold, 1, 0)
y_val_binary = np.where(y_val >= threshold, 1, 0)

# %%
accuracy = accuracy_score(y_val_binary, y_pred_binary)

# %%
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7452093683463449

# %%
import pickle

# %%
with open('model.bin', 'wb') as f_out:
    pickle.dump((dv, model), f_out)

# %%
with open('model.bin', 'wb') as f_out:
    pickle.dump((dv, model), f_out)

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is F6EE-95F7
#
#  Directory of C:\Users\Murthy
#
# 15-07-2024  11:51    <DIR>          .
# 01-03-2023  06:33    <DIR>          ..
# 13-07-2024  08:44    <DIR>          .anaconda
# 24-11-2023  12:50    <DIR>          .android
# 26-03-2024  11:11    <DIR>          .arduinoIDE
# 12-06-2024  17:17    <DIR>          .cache
# 14-07-2024  11:22    <DIR>          .conda
# 13-07-2024  08:36                25 .condarc
# 13-07-2024  08:35    <DIR>          .continuum
# 24-11-2023  16:34    <DIR>          .gradle
# 14-07-2024  17:15    <DIR>          .ipynb_checkpoints
# 14-07-2024  08:30    <DIR>          .ipython
# 14-07-2024  17:11    <DIR>          .jupyter
# 14-07-2024  11:17    <DIR>          .matplotlib
# 09-05-2024  23:11               127 .npmrc
# 10-05-2024  17:49               364 .packettracer
# 24-11-2023  22:42    <DIR>          .redhat
# 25-03-2023  15:25    <DIR>          .VirtualBox
# 15-06-2023  18:56    <DIR>          .vscode
# ...
